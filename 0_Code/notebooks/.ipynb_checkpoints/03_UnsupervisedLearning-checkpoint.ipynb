# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_excel('../data_archives/df_processed.xlsx')
data = data[data['WeekTotals']>0].reset_index()
data_labels = data[['name','mapped_venue_type','lat','long']]
data = data.drop(['index','lat','long','google_id','venue_type','WeekTotals','name','mapped_venue_type','level_0','activity_cluster'],axis=1)
print("Business/Venue dataset has {} records with {} features each".format(*data.shape))
data.head()
# Out:
# Business/Venue dataset has 1723 records with 7 features each
#    Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0     443      531        506       519     514       144      40
# 1     443      531        506       519     514       144      40
# 2     443      531        506       519     514       144      40
# 3     443      531        506       519     514       144      40
# 4     443      531        506       519     514       144      40

# %%
display(data.describe())
# Out:
#             Monday      Tuesday    Wednesday     Thursday       Friday  \
# count  1723.000000  1723.000000  1723.000000  1723.000000  1723.000000
# mean    379.543819   412.717353   407.250145   438.252467   497.770749
# std     176.533785   195.476881   185.133268   170.967621   170.640017
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     242.000000   236.000000   249.000000   297.000000   387.000000
# 50%     357.000000   387.000000   396.000000   401.000000   461.000000
# 75%     443.000000   531.000000   506.000000   519.000000   514.000000
# max    1122.000000  1196.000000  1158.000000  1233.000000  1353.000000
#
#           Saturday       Sunday
# count  1723.000000  1723.000000
# mean    371.404527   270.431805
# std     215.107030   213.675578
# min       0.000000     0.000000
# 25%     144.000000    40.000000
# 50%     429.000000   334.000000
# 75%     429.000000   334.000000
# max    1139.000000  1071.000000

# %%
import seaborn as sns
sns.pairplot(data=data, diag_kind='kde')

# %%
sns.heatmap(data.corr(), annot=True)

# %%
log_data = np.log(data)
sns.pairplot(log_data, diag_kind='kde')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## PCA Dimmensionality Reduction

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2).fit(data)

reduced_data = pca.transform(data)

reduced_data = pd.DataFrame(reduced_data, columns=['Dimension_1','Dimension_2'])

# %%
fig, ax = plt.subplots(figsize=(10,10))

#scatterplot of reduced data
ax.scatter(x=reduced_data.loc[:,'Dimension_1'],y=reduced_data.loc[:,'Dimension_2'],facecolors='b',edgecolors='b',
          s=70, alpha=0.5)

feature_vectors = pca.components_.T

arrow_size, text_pos = 800.0, 800.0

for i, v in enumerate(feature_vectors):
        ax.arrow(0, 0, arrow_size*v[0], arrow_size*v[1], 
                  head_width=0.2, head_length=0.2, linewidth=2, color='red')
        ax.text(v[0]*text_pos, v[1]*text_pos, data.columns[i], color='black', 
                 ha='center', va='center', fontsize=18)
        
ax.set_xlabel("Dimension 1", fontsize=14)
ax.set_ylabel("Dimension 2", fontsize=14)
ax.set_title("PC plane with original feature projections.", fontsize=16)
# Out:
# Text(0.5,1,'PC plane with original feature projections.')

# %% [markdown]
# ## KMeans Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

KMeans_clusterer = KMeans(n_clusters=4).fit(reduced_data)

preds = KMeans_clusterer.predict(reduced_data)

centers = KMeans_clusterer.cluster_centers_

score = silhouette_score(reduced_data, preds)
print("KMeans Clusters with a silhouette score of:",score)
# Out:
# KMeans Clusters with a silhouette score of: 0.853580216853

# %%
import matplotlib.cm as cm
fig, ax = plt.subplots(figsize=(14,8))

predictions = pd.DataFrame(preds, columns=['Cluster'])
plot_data = pd.concat([predictions, reduced_data], axis=1)

cmap = cm.get_cmap('Oranges_r')

#plot points based on assigned cluster
for i, cluster in plot_data.groupby('Cluster'):
    cluster.plot(ax=ax, kind='scatter',x='Dimension_1', y = 'Dimension_2',
                 color = cmap((i)*1.0/(len(centers)-1)), label = 'Cluster %i'%(i), s=30, edgecolors='black')
    
#plot centers with indicators    
for i, c in enumerate(centers):
    ax.scatter(x=c[0], y=c[1], color = 'white', edgecolors='black', \
              alpha = 1, linewidth = 2, marker = 'o', s=200)
    ax.scatter(x=c[0], y=c[1], marker='$%d$'%(i), alpha=1,s=100)
    
#set plot title
ax.set_title("Cluster Learning on PCA_Reduced Data")
# Out:
# Text(0.5,1,'Cluster Learning on PCA_Reduced Data')

# %%
true_centers = pca.inverse_transform(centers)
segments = ['Segment {}'.format(i) for i in range(0,len(centers))]
true_centers = pd.DataFrame(np.round(true_centers),columns=data.keys())
true_centers.index = segments
display(true_centers)
# Out:
#            Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# Segment 0   236.0    235.0      244.0     292.0   381.0     423.0   328.0
# Segment 1   443.0    531.0      506.0     519.0   514.0     142.0    38.0
# Segment 2   737.0    758.0      749.0     763.0   879.0     760.0   644.0
# Segment 3   450.0    448.0      453.0     489.0   603.0     621.0   518.0

# %%
import geopandas as gpd
import pysal as ps
from pysal.contrib.viz import mapping as maps

palette=["C2"] #["C0", "C1", "k","C2"]

#figure size
plot_size = (12,11)

x_min = -71.07
y_min = 42.3425
x_max = -71.05
y_max = 42.356

building_shapefile_path = '../resources/boston_buildings.shp'
shapefile_path = '../resources/Hydrography_Polygon.shp'
building_shapefile = gpd.read_file(building_shapefile_path)
shapefile = gpd.read_file(shapefile_path) #shapefile of boston waterway

#configure shapefile projection
building_shapefile = building_shapefile.to_crs({'init': 'epsg:4326'}) 

clustered_data = pd.concat([plot_data, data_labels],axis=1)
fig, ax = plt.subplots(figsize=plot_size)

#define plot ranges
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])

ax = building_shapefile.plot(ax=ax,alpha=.5,edgecolor='grey',facecolor='#ffffff')
ax = shapefile.plot(ax=ax,alpha=1,edgecolor='grey',facecolor='#f2f7ff')
sns.scatterplot(x='long',y='lat',data=clustered_data[clustered_data['Cluster']==3],hue='Cluster',s=400,palette=palette,alpha=.5)
plt.savefig("../data_archives/plot_exports/180824/cluster_plotcolor_3.jpg", dpi=300,
            papertype=None, format=None,
            transparent=False, bbox_inches=None, pad_inches=0.1,
            frameon=None)

# %%
from scipy.stats import mode

venue_types = list(set(clustered_data['mapped_venue_type'].values))

c = []
d = []

for item in venue_types:
    v = item
    m = mode(clustered_data[clustered_data['mapped_venue_type']==item]['Cluster'])[0]
    c.append(v)
    d.append(m[0])

cluster_groups = pd.DataFrame({'type':c, 'cluster':d})
cluster_groups.sort_values(by='cluster')
# Out:
#                      type  cluster
# 0               education        0
# 5   professional_services        0
# 6              automotive        0
# 7              government        0
# 10        health_wellness        0
# 13                finance        0
# 1                    food        1
# 3                  retail        1
# 4                 grocery        1
# 8   culture_entertainment        1
# 12                  other        1
# 9          transportation        2
# 2                religous        3
# 11                    bar        3

# %%
seg_plot_data = true_centers.transpose()
seg_plot_data = seg_plot_data.reset_index()
seg_plot_data['Day'] = seg_plot_data['index']
seg_plot_data.drop('index',axis=1,inplace=True)

for i in range(len(seg_plot_data)):
    seg_plot_data.at[i,'Day'] = "{}_{}".format(i,seg_plot_data.loc[i]['Day'])
seg_plot_data
# Out:
#    Segment 0  Segment 1  Segment 2  Segment 3          Day
# 0      473.0      428.0      812.0      181.0     0_Monday
# 1      565.0      439.0      838.0      217.0    1_Tuesday
# 2      540.0      429.0      829.0      200.0  2_Wednesday
# 3      549.0      467.0      837.0      247.0   3_Thursday
# 4      541.0      581.0      951.0      308.0     4_Friday
# 5      145.0      612.0      788.0      287.0   5_Saturday
# 6       39.0      509.0      668.0      195.0     6_Sunday

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15,11))
sns.lineplot(x=seg_plot_data['Day'],y=seg_plot_data['Segment 0'],color=palette[0])
sns.lineplot(x=seg_plot_data['Day'],y=seg_plot_data['Segment 1'],color=palette[1])
sns.lineplot(x=seg_plot_data['Day'],y=seg_plot_data['Segment 2'],color=palette[2])
sns.lineplot(x=seg_plot_data['Day'],y=seg_plot_data['Segment 3'],color=palette[3])
plt.xticks(size=8)
plt.yticks(size=8)
plt.xlabel('day of week',fontsize=10)
plt.ylabel('activity count',fontsize=10)
plt.title('Weekly Aggregate Activity Profiles',fontsize=16, loc='left')
labels=seg_plot_data.columns
plt.legend(labels,loc='upper left')

plt.savefig("../data_archives/plot_exports/180824/cluster_pattern.jpg", dpi=300,
            papertype=None, format=None,
            transparent=False, bbox_inches=None, pad_inches=0.1,
            frameon=None)

# %%
cluster_map = {'other':'1',
               'bar':'1',
               'food':'1',
               'religous':'1',
               'retail':'1',
               'culture_entertainment':'1',
               'transportation':'0',
               'grocery':'0',
               'health_wellness':'2',
               'government':'2',
               'automotive':'2',
               'professional_services':'2',
               'finance':'2',
               'education':'2'}
cluster_activity_map = {'0':{'Monday':718,'Tuesday':738,'Wednesday':729,'Thursday':745,'Friday':861,'Saturday':753,'Sunday':638},
                        '1':{'Monday':242,'Tuesday':236,'Wednesday':249,'Thursday':297,'Friday':387,'Saturday':429,'Sunday':334},
                        '2':{'Monday':443,'Tuesday':531,'Wednesday':506,'Thursday':519,'Friday':514,'Saturday':144,'Sunday':40},
                        '3':{'Monday':443,'Tuesday':455,'Wednesday':445,'Thursday':482,'Friday':597,'Saturday':621,'Sunday':518}}

# %%
df = pd.read_excel('../data_archives/df_processed.xlsx')
df.head()
# Out:
#    index                        name        lat       long  \
# 0      0    McMahon & Associates, PC  42.352366 -71.056066
# 1      1          Barclay Damon, LLP  42.352321 -71.056248
# 2      2  Request Health Corporation  42.351584 -71.056269
# 3      3                     StackUp  42.351586 -71.056323
# 4      4                        KPMG  42.351781 -71.056737
#
#                      google_id  \
# 0  ChIJddqFA4Jw44kRHz6p3qWTs4c
# 1  ChIJD75e1YBw44kRvDZoMEj44jY
# 2  ChIJv1J9rnh644kR4hc29XVaEFg
# 3  ChIJY_v-pXh744kRub1hj4RNwkk
# 4  ChIJDaRRe4Jw44kRjXWBXIsFgj0
#
#                                           venue_type  Monday  Tuesday  \
# 0  ['accounting', 'lawyer', 'finance', 'point_of_...       0        0
# 1  ['accounting', 'lawyer', 'finance', 'point_of_...       0        0
# 2  ['accounting', 'finance', 'point_of_interest',...       0        0
# 3  ['accounting', 'finance', 'point_of_interest',...       0        0
# 4  ['accounting', 'finance', 'point_of_interest',...       0        0
#
#    Wednesday  Thursday  Friday  Saturday  Sunday  WeekTotals mapped_venue_type
# 0          0         0       0         0       0           0           finance
# 1          0         0       0         0       0           0           finance
# 2          0         0       0         0       0           0           finance
# 3          0         0       0         0       0           0           finance
# 4          0         0       0         0       0           0           finance

# %%
ac = []
for i in range(len(df)):
    clust = cluster_map[df.iloc[i]['mapped_venue_type']]
    ac.append(clust)
    if df.loc[i]['WeekTotals'] == 0:
        df.at[i,'Monday'] = cluster_activity_map[clust]['Monday']
        df.at[i,'Tuesday'] = cluster_activity_map[clust]['Tuesday']
        df.at[i,'Wednesday'] = cluster_activity_map[clust]['Wednesday']
        df.at[i,'Thursday'] = cluster_activity_map[clust]['Thursday']
        df.at[i,'Friday'] = cluster_activity_map[clust]['Friday']
        df.at[i,'Saturday'] = cluster_activity_map[clust]['Saturday']
        df.at[i,'Sunday'] = cluster_activity_map[clust]['Sunday']
        df.at[i, 'WeekTotals'] = sum(df.iloc[i][['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']])

df['activity_cluster'] = ac    
df.head()
# Out:
#    index                        name        lat       long  \
# 0      0    McMahon & Associates, PC  42.352366 -71.056066
# 1      1          Barclay Damon, LLP  42.352321 -71.056248
# 2      2  Request Health Corporation  42.351584 -71.056269
# 3      3                     StackUp  42.351586 -71.056323
# 4      4                        KPMG  42.351781 -71.056737
#
#                      google_id  \
# 0  ChIJddqFA4Jw44kRHz6p3qWTs4c
# 1  ChIJD75e1YBw44kRvDZoMEj44jY
# 2  ChIJv1J9rnh644kR4hc29XVaEFg
# 3  ChIJY_v-pXh744kRub1hj4RNwkk
# 4  ChIJDaRRe4Jw44kRjXWBXIsFgj0
#
#                                           venue_type  Monday  Tuesday  \
# 0  ['accounting', 'lawyer', 'finance', 'point_of_...     443      531
# 1  ['accounting', 'lawyer', 'finance', 'point_of_...     443      531
# 2  ['accounting', 'finance', 'point_of_interest',...     443      531
# 3  ['accounting', 'finance', 'point_of_interest',...     443      531
# 4  ['accounting', 'finance', 'point_of_interest',...     443      531
#
#    Wednesday  Thursday  Friday  Saturday  Sunday  WeekTotals  \
# 0        506       519     514       144      40        2697
# 1        506       519     514       144      40        2697
# 2        506       519     514       144      40        2697
# 3        506       519     514       144      40        2697
# 4        506       519     514       144      40        2697
#
#   mapped_venue_type activity_cluster
# 0           finance                2
# 1           finance                2
# 2           finance                2
# 3           finance                2
# 4           finance                2

# %%
df.to_excel('../data_archives/df_processed.xlsx')

# %%
import pandas as pd

# %%
df = pd.read_excel('../data_archives/df_processed.xlsx')

# %%
set(df['activity_cluster'].values)
# Out:
# {0, 1, 2}

# %%
df
# Out:
#       index                                               name        lat  \
# 0         0                           McMahon & Associates, PC  42.352366
# 1         1                                 Barclay Damon, LLP  42.352321
# 2         2                         Request Health Corporation  42.351584
# 3         3                                            StackUp  42.351586
# 4         4                                               KPMG  42.351781
# 5         5                                 Baker Newman Noyes  42.353232
# 6         6                         Adler Pollock & Sheehan PC  42.353291
# 7         7                                Daigle & Associates  42.353588
# 8         8                DGC (DiCicco, Gulman & Company LLP)  42.353649
# 9         9                      Matson, Driscoll & Damico LLP  42.353653
# 10       10             Jefferson Wells International - Boston  42.353755
# 11       11                                     Meaden & Moore  42.353755
# 12       12                       Rackemann, Sawyer & Brewster  42.354055
# 13       13                                St Yves David A CPA  42.354035
# 14       14                                            AAFCPAs  42.354074
# 15       15    Soiref, Gary A CPA - Parent Mc Laughlin & Nagle  42.354075
# 16       16   Kennedy James G Cpa - Parent Mc Laughlin & Nagle  42.354075
# 17       17        Parent Mc Laughlin & Nagle: Ciampa John CPA  42.354075
# 18       18                                          botkeeper  42.350304
# 19       19                                     Edelstein & Co  42.354131
# 20       20                                 A2 Global Shipping  42.350061
# 21       21             Massachusetts General Hospital Helipad  42.363638
# 22       22                      Boston City Hospital Heliport  42.333613
# 23       23             Maverick St. Resident Gate East Boston  42.365290
# 24       24                        Car rental , Boston Airport  42.368042
# 25       25      Boston Logan International Airport Terminal B  42.362037
# 26       26                                      Logan Airport  42.366134
# 27       27  JetBlue Airways (Maintenance-Materials) Hangar...  42.374258
# 28       28  Boston Logan International Airport - Terminal ...  42.366628
# 29       29  Signature Flight Support BOS - Boston Logan In...  42.374899
# ...     ...                                                ...        ...
# 1693   5293                                    Highball Lounge  42.357395
# 1694   5330                                    Shoppers' Plaza  42.356139
# 1695   5331                           Norman B. Leventhal Park  42.356166
# 1696   5333                                 Post Office Square  42.356514
# 1697   5347                                        SP+ Parking  42.353565
# 1698   5348                           99 Summer Street Parking  42.353591
# 1699   5349                                        Parking Lot  42.353611
# 1700   5353                                Kingston St Parking  42.353776
# 1701   5390                                      Gary Drug Co.  42.357751
# 1702   5392                       Afferent Pharmaceuticals Inc  42.352427
# 1703   5404                  Kennedy Brothers Physical Therapy  42.355485
# 1704   5453          Massachusetts State Police Marine Section  42.368127
# 1705   5481                      Lincoln Street Property Owner  42.352726
# 1706   5486                       Vesper Investment Properties  42.352999
# 1707   5487                              A/E/C Solutions, Inc.  42.353055
# 1708   5491                             GE Capital Real Estate  42.353100
# 1709   5492                              Penrod Properties Inc  42.353075
# 1710   5508                                           minigrow  42.353197
# 1711   5510                             Chipotle Mexican Grill  42.353419
# 1712   5513                                     Hot Pot Buffet  42.351289
# 1713   5532             The YMCA International Learning Center  42.355762
# 1714   5533                       Spruce Street Nursery School  42.353264
# 1715   5553                                  Boston's Sun Spot  42.359689
# 1716   5591                               Empire Beauty School  42.354665
# 1717   5593                         Boston Pain Relief Massage  42.356844
# 1718   5615                                            大中华中国超市  42.352125
# 1719   5618                            Logowitz & Co Designers  42.351430
# 1720   5622                                         Wrap It Up  42.351298
# 1721   5626                              BFS Business Printing  42.351349
# 1722   5629                                    ProPrint Boston  42.351108
#
#            long                    google_id  \
# 0    -71.056066  ChIJddqFA4Jw44kRHz6p3qWTs4c
# 1    -71.056248  ChIJD75e1YBw44kRvDZoMEj44jY
# 2    -71.056269  ChIJv1J9rnh644kR4hc29XVaEFg
# 3    -71.056323  ChIJY_v-pXh744kRub1hj4RNwkk
# 4    -71.056737  ChIJDaRRe4Jw44kRjXWBXIsFgj0
# 5    -71.056267  ChIJA_c0BIJw44kRC-aqIwcaXdQ
# 6    -71.056333  ChIJYVdYIoJw44kRP0BOts8EKeQ
# 7    -71.055850  ChIJjztu9oNw44kRYm6oIVKU4r8
# 8    -71.056467  ChIJZSp0PIJw44kRRfNJO3f-31M
# 9    -71.056638  ChIJL45a8Xh644kRCUlKYMwqJck
# 10   -71.056416  ChIJCRW2OoJw44kRvvUyc2lMILw
# 11   -71.056416  ChIJCRW2OoJw44kRpLFqpfbQ448
# 12   -71.055910  ChIJ30VlLIJw44kRI1VbDKAZUNs
# 13   -71.056080  ChIJ30VlLIJw44kRXncUfflLgsg
# 14   -71.055802  ChIJ5TNqKoJw44kRHpSUbsZAMgU
# 15   -71.055850  ChIJ30VlLIJw44kRjXj1TcldUwY
# 16   -71.055850  ChIJ30VlLIJw44kRYbl0g0hR78Q
# 17   -71.055850  ChIJ30VlLIJw44kR6S0pi9vnQqI
# 18   -71.057101  ChIJqUo43Xh644kRQ0VsbEQTmgo
# 19   -71.055962  ChIJKbYEhIRw44kRbesrXs_-t2c
# 20   -71.057658  ChIJS77f43h644kRQc4sJQ1L1yM
# 21   -71.069183  ChIJEbOZ35lw44kRmmZFeEjhHMA
# 22   -71.071667  ChIJHX-MW0B644kR_QxmIrjQj5Y
# 23   -71.027583  ChIJyZ04lmpw44kRY5fzJhNw_MY
# 24   -71.030175  ChIJ5-DC00Fw44kRJLh-UF1JFRE
# 25   -71.018735  ChIJUb5TihZw44kR9_OGjr5zC1M
# 26   -71.019353  ChIJW0edVdlx44kRXmx05qojoT0
# 27   -71.024628  ChIJmd9BFjhw44kRHqSMe4nZ2a4
# 28   -71.016505  ChIJg2ZBvj1w44kR3-BflPVz6n8
# 29   -71.023227  ChIJnfWx5Ddw44kRKctc5RWyWLg
# ...         ...                          ...
# 1693 -71.060689  ChIJS_70V4Nw44kRwRENtu0e6Rg
# 1694 -71.059499  ChIJzxWLbYNw44kRjAbJLH1eIvQ
# 1695 -71.055534  ChIJn3ppVoFw44kRVWGGca4l4rw
# 1696 -71.055847  ChIJLyhN_oNw44kRa_vE81OeW_E
# 1697 -71.058762  ChIJ8xRV9IJw44kRgqSK41Iaqo0
# 1698 -71.058777  ChIJ63MSXIJw44kR7xZCv4NvUmQ
# 1699 -71.058769  ChIJOaZL9YJw44kRGNbUvg5zD4I
# 1700 -71.058698  ChIJTSpU9IJw44kRSNO7CQvew_U
# 1701 -71.070108  ChIJhZbg5p5w44kR7fhcf-EOwtE
# 1702 -71.072750  ChIJ5QjK2XR644kRLYO2VZHddFY
# 1703 -71.058976  ChIJM7i_CINw44kRBO0dil-fFYE
# 1704 -71.060999  ChIJ02CN8o1w44kRjdGweoWYizM
# 1705 -71.058444  ChIJPaVhZYJw44kRgmRCHhLJ60A
# 1706 -71.057489  ChIJfyX6j39w44kRpvrRQOmLQKM
# 1707 -71.057530  ChIJf20_bIJw44kR7xwc5OQzK_Y
# 1708 -71.057404  ChIJeUH0a4Jw44kRb8YqSmbV3bE
# 1709 -71.058292  ChIJLRsZZoJw44kR1-XPwz4G8GE
# 1710 -71.057416  ChIJq6oabIJw44kRLYv-5G4nsoA
# 1711 -71.057978  ChIJQfjoXIJw44kREUr2WpbUgYs
# 1712 -71.059753  ChIJ77emQXh644kR3SNyh2nzXPs
# 1713 -71.057425  ChIJnQvI54Rw44kRShmpUO8grzE
# 1714 -71.062706  ChIJawYwWZ1w44kRA6NbCmXpteg
# 1715 -71.055952  ChIJb7nX2YVw44kRighz2aEqh0I
# 1716 -71.062696  ChIJ03sbO51w44kRBFwu4_-h98c
# 1717 -71.059071  ChIJP6V3WoJw44kR6j_1XODjwGA
# 1718 -71.058170  ChIJ24Cvg3h644kR50r3bgm86cM
# 1719 -71.057597  ChIJfae3lXh644kRRZMFG9XiJwQ
# 1720 -71.058229  ChIJc65gjHh644kRjsOgHG_PMWU
# 1721 -71.057086  ChIJg3GdgnR644kRjOnao9hAL8w
# 1722 -71.057446  ChIJp9zb_nR644kR-kbb7FIlbWc
#
#                                              venue_type  Monday  Tuesday  \
# 0     ['accounting', 'lawyer', 'finance', 'point_of_...     443      531
# 1     ['accounting', 'lawyer', 'finance', 'point_of_...     443      531
# 2     ['accounting', 'finance', 'point_of_interest',...     443      531
# 3     ['accounting', 'finance', 'point_of_interest',...     443      531
# 4     ['accounting', 'finance', 'point_of_interest',...     443      531
# 5     ['accounting', 'finance', 'point_of_interest',...     443      531
# 6     ['accounting', 'lawyer', 'finance', 'point_of_...     443      531
# 7     ['accounting', 'finance', 'point_of_interest',...     443      531
# 8     ['accounting', 'finance', 'point_of_interest',...     443      531
# 9     ['accounting', 'finance', 'point_of_interest',...     443      531
# 10    ['accounting', 'finance', 'point_of_interest',...     443      531
# 11    ['accounting', 'finance', 'point_of_interest',...     443      531
# 12    ['lawyer', 'accounting', 'finance', 'point_of_...     443      531
# 13    ['accounting', 'finance', 'point_of_interest',...     443      531
# 14    ['accounting', 'finance', 'point_of_interest',...     443      531
# 15    ['accounting', 'finance', 'point_of_interest',...     443      531
# 16    ['accounting', 'finance', 'point_of_interest',...     443      531
# 17    ['accounting', 'finance', 'point_of_interest',...     443      531
# 18    ['accounting', 'finance', 'point_of_interest',...     443      531
# 19    ['accounting', 'finance', 'point_of_interest',...     498      430
# 20    ['airport', 'moving_company', 'finance', 'stor...     718      738
# 21    ['airport', 'point_of_interest', 'establishment']     718      738
# 22    ['airport', 'point_of_interest', 'establishment']     718      738
# 23    ['airport', 'point_of_interest', 'establishment']     718      738
# 24    ['airport', 'point_of_interest', 'establishment']     718      738
# 25    ['airport', 'point_of_interest', 'establishment']     718      738
# 26    ['airport', 'point_of_interest', 'establishment']     718      738
# 27    ['airport', 'point_of_interest', 'establishment']     624      616
# 28    ['airport', 'point_of_interest', 'establishment']     718      738
# 29    ['airport', 'premise', 'point_of_interest', 'e...     687      848
# ...                                                 ...     ...      ...
# 1693  ['bar', 'night_club', 'point_of_interest', 'es...     242      236
# 1694     ['park', 'point_of_interest', 'establishment']     242      236
# 1695     ['park', 'point_of_interest', 'establishment']     242      236
# 1696     ['park', 'point_of_interest', 'establishment']     468      665
# 1697  ['parking', 'point_of_interest', 'establishment']     718      738
# 1698  ['parking', 'point_of_interest', 'establishment']     718      738
# 1699  ['parking', 'point_of_interest', 'establishment']     718      738
# 1700  ['parking', 'point_of_interest', 'establishment']     718      738
# 1701  ['pharmacy', 'store', 'health', 'point_of_inte...     443      531
# 1702  ['pharmacy', 'store', 'health', 'point_of_inte...     443      531
# 1703  ['physiotherapist', 'health', 'point_of_intere...     443      531
# 1704   ['police', 'point_of_interest', 'establishment']     443      531
# 1705  ['real_estate_agency', 'point_of_interest', 'e...     443      531
# 1706  ['real_estate_agency', 'point_of_interest', 'e...     443      531
# 1707  ['real_estate_agency', 'finance', 'general_con...     443      531
# 1708  ['real_estate_agency', 'point_of_interest', 'e...     443      531
# 1709  ['real_estate_agency', 'point_of_interest', 'e...     443      531
# 1710  ['restaurant', 'food', 'point_of_interest', 'e...     242      236
# 1711  ['restaurant', 'food', 'point_of_interest', 'e...     582      480
# 1712  ['restaurant', 'food', 'point_of_interest', 'e...     343      249
# 1713   ['school', 'point_of_interest', 'establishment']     443      531
# 1714   ['school', 'point_of_interest', 'establishment']     443      531
# 1715  ['shoe_store', 'store', 'point_of_interest', '...     242      236
# 1716  ['beauty_salon', 'hair_care', 'spa', 'point_of...     443      531
# 1717      ['spa', 'point_of_interest', 'establishment']     443      531
# 1718    ['store', 'point_of_interest', 'establishment']     242      236
# 1719    ['store', 'point_of_interest', 'establishment']     242      236
# 1720    ['store', 'point_of_interest', 'establishment']     242      236
# 1721    ['store', 'point_of_interest', 'establishment']     439      396
# 1722    ['store', 'point_of_interest', 'establishment']     242      236
#
#       Wednesday  Thursday  Friday  Saturday  Sunday  WeekTotals  \
# 0           506       519     514       144      40        2697
# 1           506       519     514       144      40        2697
# 2           506       519     514       144      40        2697
# 3           506       519     514       144      40        2697
# 4           506       519     514       144      40        2697
# 5           506       519     514       144      40        2697
# 6           506       519     514       144      40        2697
# 7           506       519     514       144      40        2697
# 8           506       519     514       144      40        2697
# 9           506       519     514       144      40        2697
# 10          506       519     514       144      40        2697
# 11          506       519     514       144      40        2697
# 12          506       519     514       144      40        2697
# 13          506       519     514       144      40        2697
# 14          506       519     514       144      40        2697
# 15          506       519     514       144      40        2697
# 16          506       519     514       144      40        2697
# 17          506       519     514       144      40        2697
# 18          506       519     514       144      40        2697
# 19          414       474     607         0       0        2423
# 20          729       745     861       753     638        5182
# 21          729       745     861       753     638        5182
# 22          729       745     861       753     638        5182
# 23          729       745     861       753     638        5182
# 24          729       745     861       753     638        5182
# 25          729       745     861       753     638        5182
# 26          729       745     861       753     638        5182
# 27          565       433     568       396     353        3555
# 28          729       745     861       753     638        5182
# 29          873       837     631       453     586        4915
# ...         ...       ...     ...       ...     ...         ...
# 1693        249       297     387       429     334        2174
# 1694        249       297     387       429     334        2174
# 1695        249       297     387       429     334        2174
# 1696        476       757     815       978     761        4920
# 1697        729       745     861       753     638        5182
# 1698        729       745     861       753     638        5182
# 1699        729       745     861       753     638        5182
# 1700        729       745     861       753     638        5182
# 1701        506       519     514       144      40        2697
# 1702        506       519     514       144      40        2697
# 1703        506       519     514       144      40        2697
# 1704        506       519     514       144      40        2697
# 1705        506       519     514       144      40        2697
# 1706        506       519     514       144      40        2697
# 1707        506       519     514       144      40        2697
# 1708        506       519     514       144      40        2697
# 1709        506       519     514       144      40        2697
# 1710        249       297     387       429     334        2174
# 1711        463       545     596       329     253        3248
# 1712        328       314     461       646     627        2968
# 1713        506       519     514       144      40        2697
# 1714        506       519     514       144      40        2697
# 1715        249       297     387       429     334        2174
# 1716        506       519     514       144      40        2697
# 1717        506       519     514       144      40        2697
# 1718        249       297     387       429     334        2174
# 1719        249       297     387       429     334        2174
# 1720        249       297     387       429     334        2174
# 1721        406         0     669         0       0        1910
# 1722        249       297     387       429     334        2174
#
#           mapped_venue_type  activity_cluster
# 0                   finance                 2
# 1                   finance                 2
# 2                   finance                 2
# 3                   finance                 2
# 4                   finance                 2
# 5                   finance                 2
# 6                   finance                 2
# 7                   finance                 2
# 8                   finance                 2
# 9                   finance                 2
# 10                  finance                 2
# 11                  finance                 2
# 12    professional_services                 2
# 13                  finance                 2
# 14                  finance                 2
# 15                  finance                 2
# 16                  finance                 2
# 17                  finance                 2
# 18                  finance                 2
# 19                  finance                 2
# 20           transportation                 0
# 21           transportation                 0
# 22           transportation                 0
# 23           transportation                 0
# 24           transportation                 0
# 25           transportation                 0
# 26           transportation                 0
# 27           transportation                 0
# 28           transportation                 0
# 29           transportation                 0
# ...                     ...               ...
# 1693                    bar                 1
# 1694  culture_entertainment                 1
# 1695  culture_entertainment                 1
# 1696  culture_entertainment                 1
# 1697         transportation                 0
# 1698         transportation                 0
# 1699         transportation                 0
# 1700         transportation                 0
# 1701        health_wellness                 2
# 1702        health_wellness                 2
# 1703        health_wellness                 2
# 1704             government                 2
# 1705  professional_services                 2
# 1706  professional_services                 2
# 1707  professional_services                 2
# 1708  professional_services                 2
# 1709  professional_services                 2
# 1710                   food                 1
# 1711                   food                 1
# 1712                   food                 1
# 1713              education                 2
# 1714              education                 2
# 1715                 retail                 1
# 1716        health_wellness                 2
# 1717        health_wellness                 2
# 1718                 retail                 1
# 1719                 retail                 1
# 1720                 retail                 1
# 1721                 retail                 1
# 1722                 retail                 1
#
# [1723 rows x 16 columns]

# %%
import geopandas as gpd
import pysal as ps
from pysal.contrib.viz import mapping as maps
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.style.use('fivethirtyeight')

palette=["C0", "C1", "k","C2"]

#figure size
plot_size = (12,11)

x_min = -71.07
y_min = 42.3425
x_max = -71.05
y_max = 42.356

building_shapefile_path = '../resources/boston_buildings.shp'
shapefile_path = '../resources/Hydrography_Polygon.shp'
open_space_path = '../resources/open_space.shp'
building_shapefile = gpd.read_file(building_shapefile_path)
shapefile = gpd.read_file(shapefile_path) #shapefile of boston waterway
open_space_shapefile = gpd.read_file(open_space_path)

#configure shapefile projection
building_shapefile = building_shapefile.to_crs({'init': 'epsg:4326'}) 
open_space_shapefile = open_space_shapefile.to_crs({'init': 'epsg:4326'})

#clustered_data = pd.concat([plot_data, data_labels],axis=1)
fig, ax = plt.subplots(figsize=plot_size)

#define plot ranges
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])

#plot buildings
ax = building_shapefile.plot(ax=ax,alpha=.5,edgecolor='grey',facecolor='#ffffff')
#plot water
ax = shapefile.plot(ax=ax,alpha=1,edgecolor='grey',facecolor='#f2f7ff')
#plot open space
ax = open_space_shapefile.plot(ax=ax,alpha=.5,edgecolor='grey',facecolor='#bfffbf')
#plot venue locations
sns.scatterplot(x='long',y='lat',data=df,size='WeekTotals',hue='Cluster',sizes=(10, 1000),palette=palette,alpha=.5)
plt.legend(loc='upper left')
ax.legend_.remove()
plt.savefig("../data_archives/plot_exports/180824/cluster_plotcolor.jpg", dpi=300,
            papertype=None, format=None,
            transparent=False, bbox_inches=None, pad_inches=0.1,
            frameon=None)
plt.title('Activity Profiles by Location',fontsize=16, loc='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-28f93011fc8f> in <module>()
#      43 ax = open_space_shapefile.plot(ax=ax,alpha=.5,edgecolor='grey',facecolor='#bfffbf')
#      44 #plot venue locations
# ---> 45 sns.scatterplot(x='long',y='lat',data=df,size='WeekTotals',hue='activity_cluster',sizes=(10, 1000),palette=palette,alpha=.5)
#      46 plt.legend(loc='upper left')
#      47 ax.legend_.remove()
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     857         )
#     858
# --> 859         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     860         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     861         self.parse_style(plot_data["style"], markers, None, style_order)
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in parse_hue(self, data, palette, order, norm)
#     365             limits = None
#     366             levels, palette = self.categorical_to_palette(
# --> 367                 data, order, palette
#     368             )
#     369
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in categorical_to_palette(self, data, order, palette)
#     219                 if len(palette) != n_colors:
#     220                     err = "The palette list has the wrong number of colors."
# --> 221                     raise ValueError(err)
#     222                 colors = palette
#     223             else:
#
# ValueError: The palette list has the wrong number of colors.

# %%
len(df)
# Out:
# 1723
